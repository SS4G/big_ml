# %%
import pandas as pd
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import math
# %matplotlib inline

# %%
plt.figure(1)
x = np.arange(0, 60, 1)
for i in range(1, 10):
    y = 2 * np.arctan(1 / i * x) / np.pi
    plt.plot(x, y)
plt.show()

# %%
def percent(a, b):
    return abs(a - b) / b

# %%
percent(457.924, 457.269)
# Out:
# 0.0014324172423671247

# %%
percent(8151.87, 8091.78)
# Out:
# 0.007426054588730804

# %%
gain = percent(66.4108, 65.9242)

# %%
gain
# Out:
# 0.007381204474229429
